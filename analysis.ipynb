# %%
import pandas as pd

# %%
df = pd.read_csv('netflix_titles.csv')
df.columns

# %%
#Q.1
#Inspect the DataFrame with .info(), .describe(), and .head()

# %%
df.head()

# %%
df.describe()

# %%
df.info()
